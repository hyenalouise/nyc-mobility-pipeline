-- %%
--pipeline schemas
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`00-source`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`01-bronze`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`02-silver`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`03-gold`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`04-analytics`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`05-control`;

--dev schemas for experimentation
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`dev_ina`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`dev_crystal`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`dev_gab`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`dev_bri`;
CREATE SCHEMA IF NOT EXISTS `ftw-week-08`.`dev_haze`;
